# %%
# Project 4 - Machine Learning

# %%
import pandas as pd
import requests
from six import StringIO
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams.update({'font.size': 18, 'font.family': 'serif', 'xtick.major.pad' : 5, 'ytick.major.pad' : 5})

# %%
#Data importing

data_gam_url = "https://drive.google.com/uc?export=download&id=1TvbbCV-kJeNMuIORMyiMFgH_u_CQSZhX"
data_neut_url = "https://drive.google.com/uc?export=download&id=1bY6ZPF3WLxfviYSSViuw1SEx1_sWxP46"

s_gam = requests.get(data_gam_url).content
s_neut = requests.get(data_neut_url).content

data_gam = pd.read_csv(StringIO(s_gam.decode("utf-8")))
data_neut = pd.read_csv(StringIO(s_neut.decode("utf-8")))

# %%
#data_neut.head(5)

# %%
#Data sorting

data_gam.sort_values(by=['LatMom','E1', 'E1E9', 'E9E25'])
data_gam.reset_index(drop = True, inplace = True)
data_gam.head(10)

data_neut.sort_values(by=['LatMom', 'E1', 'E1E9', 'E9E25'])
data_neut.reset_index(drop = True, inplace = True)
data_neut.head(10)
# Out:
#          Th         Ph         E  NrHits  NrBumps        E1      E1E9  \
# 0   49.9085    2.28061  0.201656       4        1  0.171442  1.000000
# 1   91.4437   50.85850  0.517213      14        1  0.196177  0.452177
# 2   21.5649  -15.09720  1.376870      22        2  0.629236  0.572265
# 3   92.4443    3.56594  0.956886      18        2  0.345639  0.542478
# 4  108.5060  -84.91500  0.759574      14        1  0.491971  0.930898
# 5   97.3716   38.33720  0.915771      23        1  0.245303  0.461334
# 6   63.8539  105.98600  2.153560      34        2  1.323210  0.762178
# 7  140.9230  -77.91920  0.106224       9        1  0.028432  1.000000
# 8   62.6097  155.04700  0.456599      11        1  0.204034  0.536292
# 9  158.6000   91.10340  1.293620      29        1  0.597296  0.639848
#
#       E9E25       Z20       Z53    LatMom
# 0  1.000000  0.845587  0.026810  0.681305
# 1  0.947210  0.887481  0.024033  0.882948
# 2  0.880997  0.866884  0.015212  0.799525
# 3  0.833899  0.734324  0.049628  0.908339
# 4  0.799791  0.883198  0.011530  0.944113
# 5  0.699703  0.833461  0.027505  0.965649
# 6  0.870853  0.865712  0.019282  0.983002
# 7  1.000000  0.050571  0.016896  0.995861
# 8  1.000000  0.727547  0.069761  0.990785
# 9  0.868161  0.783006  0.014039  0.990153

# %%
#Extraction of some global statistics

data_neut[['LatMom', 'NrHits', 'NrBumps', 'E1', 'E1E9', 'E9E25', 'Z20', 'Z53', 'E', 'Ph', 'Th']].describe()
# Out:
#              LatMom        NrHits       NrBumps            E1          E1E9  \
# count  43512.000000  43512.000000  43512.000000  43512.000000  43512.000000
# mean       0.769180     13.929376      1.122564      0.341868      0.612911
# std        0.276143      8.012129      0.381821      0.229777      0.176559
# min        0.000000      1.000000      1.000000      0.006992      0.171400
# 25%        0.649031      8.000000      1.000000      0.168263      0.477409
# 50%        0.899504     13.000000      1.000000      0.299559      0.595015
# 75%        0.973680     19.000000      1.000000      0.467397      0.735480
# max        0.999937     60.000000      6.000000      2.533030      1.000000
#
#               E9E25           Z20           Z53             E            Ph  \
# count  43512.000000  43512.000000  43512.000000  43512.000000  43512.000000
# mean       0.893528      0.809153      0.034600      0.760000      0.705105
# std        0.101082      0.209241      0.056912      0.502411    103.985196
# min        0.356098      0.000000      0.000000      0.024076   -180.001000
# 25%        0.838244      0.780413      0.007268      0.366767    -89.329050
# 50%        0.916345      0.879204      0.016139      0.666409      1.788705
# 75%        0.976849      0.934041      0.034914      1.054273     90.577475
# max        1.000000      1.000000      0.779841      3.832530    180.000000
#
#                  Th
# count  43512.000000
# mean      78.625170
# std       47.212387
# min        0.499105
# 25%       37.196675
# 50%       76.319900
# 75%      118.370000
# max      178.647000
